# %%
import pandas as pd

# %%
data = pd.read_csv('contry_level_maize_climate_soil_moisture.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0355351bfa91> in <cell line: 1>()
# ----> 1 data = pd.read_csv('contry_level_maize_climate_soil_moisture.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data=pd.read_csv('contry_level_maize_climate_soil_moisture.csv')

# %%
print(data.head())
print(data.columns)
print(data.info())
# Out:
#    Unnamed: 0   Area  Year  Area Harvested (1000 HA)  Production (1000 MT)  \
# 0           0  Kenya  1960                    1050.0                1143.0
# 1           1  Kenya  1961                    1050.0                1270.0
# 2           2  Kenya  1962                    1150.0                1397.0
# 3           3  Kenya  1963                    1133.0                1400.0
# 4           4  Kenya  1964                    1133.0                1270.0
#
#    Yield (MT/HA)  dewpoint_temperature_2m (°C)  soil_temperature_level_1 (°C)  \
# 0           1.09                     15.924320                      26.955911
# 1           1.21                     16.561342                      26.655510
# 2           1.21                     15.536051                      26.981031
# 3           1.24                     16.184495                      26.623490
# 4           1.12                     15.905193                      26.726709
#
# ...

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e02734b85495> in <cell line: 1>()
# ----> 1 correlation_matrix = data.corr()
#       2 print(correlation_matrix)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
# ...

# %%
print(data.dtypes)
# Out:
# Unnamed: 0                                        int64
# Area                                             object
# Year                                              int64
# Area Harvested (1000 HA)                        float64
# Production (1000 MT)                            float64
# Yield (MT/HA)                                   float64
# dewpoint_temperature_2m (°C)                    float64
# soil_temperature_level_1 (°C)                   float64
# soil_temperature_level_2 (°C)                   float64
# soil_temperature_level_3 (°C)                   float64
# soil_temperature_level_4 (°C)                   float64
# surface_net_solar_radiation_sum (J/m^2)         float64
# temperature_2m (°C)                             float64
# temperature_2m_max (°C)                         float64
# temperature_2m_min (°C)                         float64
# total_evaporation_sum (mm)                      float64
# total_precipitation_sum (mm)                    float64
# ...

# %%
data_filtered = data.drop(columns=[data.columns[0], data.columns[1], data.columns[2]])

numeric_data = data_filtered.select_dtypes(include=['number'])

correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#                                               Area Harvested (1000 HA)  \
# Area Harvested (1000 HA)                                      1.000000
# Production (1000 MT)                                          0.898101
# Yield (MT/HA)                                                 0.349801
# dewpoint_temperature_2m (°C)                                 -0.038313
# soil_temperature_level_1 (°C)                                 0.673834
# soil_temperature_level_2 (°C)                                 0.678658
# soil_temperature_level_3 (°C)                                 0.687331
# soil_temperature_level_4 (°C)                                 0.682706
# surface_net_solar_radiation_sum (J/m^2)                       0.138079
# temperature_2m (°C)                                           0.739095
# temperature_2m_max (°C)                                       0.678953
# temperature_2m_min (°C)                                       0.768236
# ...
